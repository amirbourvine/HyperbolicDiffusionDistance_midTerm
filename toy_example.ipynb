# %%
from utils import *

# %%
points,x_points,y_points = plot_tree()

# %%
shortest_paths_mat = shortest_paths_matrix()

mat_show(shortest_paths_mat, plt.cm.viridis)

# %%
P = calc_P(shortest_paths_mat, apply_2_norm=True)

mat_show(P, plt.cm.viridis)

# %%
display_figure_B(points,x_points,y_points, shortest_paths_mat)

# %%
X = display_figure_C(shortest_paths_mat)

# %%
d_HDD = hdd(X,P)
mat_show(d_HDD, plt.cm.viridis)

print(d_HDD[0])
# Out:
# [0.         5.92429156 5.92429138 6.63898716 6.63898717 6.63898721
#  6.63898715 7.01086539 7.01086542 7.01086556 7.01086542 7.0108654
#  7.01086542 7.01086545 7.01086547 7.21320572 7.21320578 7.21320578
#  7.21320578 7.21320571 7.21320562 7.21320579 7.21320571 7.21320564
#  7.21320567 7.21320564 7.21320563 7.21320564 7.21320576 7.21320572
#  7.21320572]

# %%
display_figure_D(d_HDD)
